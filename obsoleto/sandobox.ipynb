# %%
# Iniciando Ambiente
import numpy as np
import datetime as dt
import nltk

# Se necessário, descomente as linhas a seguir para ler as stopwords
nltk.download('stopwords')
from nltk.corpus import stopwords

import unicodedata
import re 

from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\svpon\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df_original
# Out:
#              Nome                                      Desc_Catalogo  \
# 0         Martins                     *CACHACA SAO FRANCISCO 12X970M
# 1         Martins                     *CACHACA YPIOCA EMP.OURO 965ML
# 2         Martins                         *CACHACA YPIOCA OURO 965ML
# 3         Martins                        *CACHACA YPIOCA PRATA 965ML
# 4          Trilix        | BB CACHACA SAGATIBA PURA 700 ML (12) - GF
# ...           ...                                                ...
# 1015376  Atacadão     ZZZZZAUTOM.OLEO LUB.TEXXCO SAE40 CXA 1 X 24 1L
# 1015377  Atacadão      ZZZZZAUTOM.OLEO LUB.TEXXCO SAE40 UND 1 X 1 1L
# 1015378  Atacadão  ZZZZZBORRACHA PANELA TOK MULTI USO FDO 50 X 10...
# 1015379  Atacadão  ZZZZZBORRACHA PANELA TOK MULTI USO UND 1 X 1 1UND
# 1015380  Atacadão    ZZZZZLIMA K F MOTOSERRA 8 POL. CXA 1 X 100 3UND
#
#           NCM_NFe Desc_Anexo_IV  NCM_Calc_Prov  Cor_NCM_Calc     NCM_Calc  \
# 0        22084000    aguardente    220840001.0           0.0  220840001.0
# 1        22084000    aguardente    220840001.0           0.0  220840001.0
# 2        22084000    aguardente    220840001.0           0.0  220840001.0
# 3        22084000    aguardente    220840001.0           0.0  220840001.0
# 4        22040000    aguardente            NaN   220840001.0  220840001.0
# ...           ...           ...            ...           ...          ...
# 1015376  27101932           NaN            NaN           NaN          NaN
# 1015377  27101932           NaN            NaN           NaN          NaN
# 1015378  40169990           NaN            NaN           NaN          NaN
# 1015379  40169990           NaN            NaN           NaN          NaN
# 1015380  82031010           NaN            NaN           NaN          NaN
#
#          Item_Anexo_IV Prod_ST Prod_FCP
# 0                 30.0     sim      sim
# 1                 30.0     sim      sim
# 2                 30.0     sim      sim
# 3                 30.0     sim      sim
# 4                 30.0     sim      sim
# ...                ...     ...      ...
# 1015376            NaN     não      não
# 1015377            NaN     não      não
# 1015378            NaN     não      não
# 1015379            NaN     não      não
# 1015380            NaN     não      não
#
# [1015381 rows x 10 columns]
